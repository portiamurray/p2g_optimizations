# %%
import xml.etree.ElementTree as ET
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import os
# %matplotlib inline

# %%
pathcost99=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Building/Node99_TotalCost.csv'
pathco299=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Building/Node99_TotalCO2.csv'
pathco275=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Building/Node75_TotalCO2.csv'
pathcost75=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Building/Node75_TotalCost.csv'
pathco250=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Building/Node50new_TotalCO2.csv'
pathcost50=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Building/Node50new_TotalCost.csv'
pathco225=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Building/Node25_TotalCO2.csv'
pathcost25=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Building/Node25_TotalCost.csv'
bcost99=pd.read_csv(pathcost99)
bco299=pd.read_csv(pathco299)
bcost75=pd.read_csv(pathcost75)
bco275=pd.read_csv(pathco275)
bcost50=pd.read_csv(pathcost50)
bco250=pd.read_csv(pathco250)
bcost25=pd.read_csv(pathcost25)
bco225=pd.read_csv(pathco225)
bobjectives=pd.read_csv(r'/Users/portia_murray/Dropbox/PhD/ICAE data/Building/Objectives_Cost.csv')
bobjectives[32:50]
# Out:
#     Unnamed: 0     TotalCost      TotalCO2
# 32          33  13468.603624  19680.130766
# 33          34  11247.696439  15633.112249
# 34          35  34993.129194  51665.135834
# 35          36  14142.924792  14761.582024
# 36          37  17683.370446  27366.550725
# 37          38  29090.510623  57918.745805
# 38          39   9564.837853   7798.892014
# 39          40  32493.757814  73232.375258
# 40          41   9933.001680  17047.839780
# 41          42  16354.076088  30162.802160
# 42          43  26724.217263  43893.192891
# 43          44  26000.442568  51518.038698
# 44          45   5898.549511   3751.650248
# 45          46  17204.659578  17143.690990
# 46          47  12955.950607  21893.432602
# 47          48   7706.519538   5992.441418
# 48          49  18118.112374  31442.064478
# 49          50  18718.535451  36244.905877

# %%
#neighbourhood
ncostcost=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Neigh/Objectives_Cost.csv'
nobjectives=pd.read_csv(ncostcost)
nobjectives
# Out:
#     Unnamed: 0      TotalCost       TotalCO2
# 0            1  149515.969300  284284.161866
# 1            2  251549.814472  376035.985667
# 2            3  209516.205730  363194.493743
# 3            4  191081.293841  303074.238342
# 4            5  185847.579987  361234.238942
# 5            6  218676.305488  461658.849044
# 6            7  197190.517523  306615.259878
# 7            8  173186.118414  311115.995606
# 8            9  246385.644636  429363.266558
# 9           10  161684.598829  270624.214830
# 10          11  210555.035987  337814.563260
# 11          12  183225.626862  339526.136657
# 12          13  170742.515667  230791.374260
# 13          14  160632.494502  233205.591408
# 14          15  145769.524187  231633.968115
# 15          16  134659.503912  213580.241512
# 16          17  155607.885174  304144.769567
# 17          18  206626.439653  324650.139575

# %%
Buildings=pd.DataFrame(index=range(1,6),columns=['Total Cost','Total CO2'])

# %%
Buildings.loc[1,'Total Cost']=bobjectives['TotalCost'].sum()
Buildings.loc[1,'Total CO2']=bobjectives['TotalCO2'].sum()
Buildings.loc[2,'Total Cost']=bcost25['TotalCost'].sum()
Buildings.loc[2,'Total CO2']=bco225['TotalCO2'].sum()
Buildings.loc[3,'Total Cost']=bcost50['TotalCost'].sum()
Buildings.loc[3,'Total CO2']=bco250['TotalCO2'].sum()
Buildings.loc[4,'Total Cost']=bcost75['TotalCost'].sum()
Buildings.loc[4,'Total CO2']=bco275['TotalCO2'].sum()
Buildings.loc[5,'Total Cost']=bcost99['TotalCost'].sum()
Buildings.loc[5,'Total CO2']=bco299['TotalCO2'].sum()
Buildings
# Out:
#     Total Cost    Total CO2
# 1  3.84536e+06  5.60325e+06
# 2  3.88029e+06  4.49484e+06
# 3   3.9768e+06  3.36989e+06
# 4  4.14164e+06  2.27871e+06
# 5  5.13628e+06  1.25661e+06

# %%
Neigh=pd.DataFrame(index=range(1,6),columns=['Total Cost','Total CO2'])

# %%
npathcost99=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Neigh/NNode99_TotalCost.csv'
npathco299=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Neigh/NNode99_TotalCO2.csv'
npathco275=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Neigh/NNode75_TotalCO2.csv'
npathcost75=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Neigh/NNode75_TotalCost.csv'
npathco250=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Neigh/NNode50_TotalCO2.csv'
npathcost50=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Neigh/NNode50_TotalCost.csv'
npathco225=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Neigh/NNode25_TotalCO2.csv'
npathcost25=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Neigh/NNode25_TotalCost.csv'
ncost99=pd.read_csv(npathcost99)
nco299=pd.read_csv(npathco299)
ncost75=pd.read_csv(npathcost75)
nco275=pd.read_csv(npathco275)
ncost50=pd.read_csv(npathcost50)
nco250=pd.read_csv(npathco250)
ncost25=pd.read_csv(npathcost25)
nco225=pd.read_csv(npathco225)
nobjectives=pd.read_csv(r'/Users/portia_murray/Dropbox/PhD/ICAE data/Neigh/Objectives_Cost.csv')
ncost50
# Out:
#     Unnamed: 0      TotalCost
# 0            1  158528.844953
# 1            2  263213.341091
# 2            3  221862.746323
# 3            4  200796.063650
# 4            5  199119.292537
# 5            6  233916.489674
# 6            7  208691.587646
# 7            8  184394.920862
# 8            9  260415.285777
# 9           10  170420.358214
# 10          11  222827.129222
# 11          12  195147.369254
# 12          13  182827.174259
# 13          14  169883.654550
# 14          15  155380.774190
# 15          16  142542.338545
# 16          17  166239.910048
# 17          18  218686.537293

# %%
Neigh.loc[1,'Total Cost']=nobjectives['TotalCost'].sum()+173179.31266737776
Neigh.loc[1,'Total CO2']=nobjectives['TotalCO2'].sum()
Neigh.loc[2,'Total Cost']=ncost25['TotalCost'].sum()+173179.31266737776
Neigh.loc[2,'Total CO2']=nco225['TotalCO2'].sum()
Neigh.loc[3,'Total Cost']=ncost50['TotalCost'].sum()+173179.31266737776
Neigh.loc[3,'Total CO2']=nco250['TotalCO2'].sum()
Neigh.loc[4,'Total Cost']=ncost75['TotalCost'].sum()+173179.31266737776
Neigh.loc[4,'Total CO2']=nco275['TotalCO2'].sum()
Neigh.loc[5,'Total Cost']=ncost99['TotalCost'].sum()+173179.31266737776
Neigh.loc[5,'Total CO2']=nco299['TotalCO2'].sum()
Neigh
# Out:
#     Total Cost    Total CO2
# 1  3.52563e+06  5.68255e+06
# 2  3.60259e+06  4.59869e+06
# 3  3.72807e+06  3.51484e+06
# 4  3.93409e+06  2.43099e+06
# 5  4.43037e+06  1.36456e+06

# %%
cost50=pd.read_csv(r'/Users/portia_murray/Dropbox/PhD/ICAE data/Neigh/NNode50_TotalCost2.csv')

# %%
co250=pd.read_csv(r'/Users/portia_murray/Dropbox/PhD/ICAE data/Neigh/NNode50_TotalCO2.csv')

# %%
co250
# Out:
#     Unnamed: 0       TotalCO2
# 0            1  168270.900584
# 1            2  240464.136849
# 2            3  224230.287596
# 3            4  188989.087890
# 4            5  218636.857982
# 5            6  271848.125368
# 6            7  193495.365942
# 7            8  191159.110997
# 8            9  266001.266752
# 9           10  167528.533342
# 10          11  211955.141066
# 11          12  206578.878020
# 12          13  149919.012684
# 13          14  149988.856813
# 14          15  145622.729178
# 15          16  132650.097397
# 16          17  182660.714801
# 17          18  204841.986791

# %%
Community=pd.DataFrame(index=range(1,4),columns=['Total Cost','Total CO2'])

# %%
cpathcost99=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Community/CNode99_TotalCost.csv'
cpathco299=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Community/CNode99_TotalCO2.csv'
cpathco275=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Community/CNode75_TotalCO2.csv'
cpathcost75=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Community/CNode75_TotalCost.csv'
cpathco250=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Community/CNode50_TotalCO2.csv'
cpathcost50=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Community/CNode50_TotalCost.csv'
cpathco225=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Community/CNode25_TotalCO2.csv'
cpathcost25=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Community/CNode25_TotalCost.csv'
ccost99=pd.read_csv(cpathcost99)
cco299=pd.read_csv(cpathco299)
ccost75=pd.read_csv(cpathcost75)
cco275=pd.read_csv(cpathco275)
ccost50=pd.read_csv(cpathcost50)
cco250=pd.read_csv(cpathco250)
ccost25=pd.read_csv(cpathcost25)
cco225=pd.read_csv(cpathco225)
cobjectives=pd.read_csv(r'/Users/portia_murray/Dropbox/PhD/ICAE data/Community/Objectives_Cost.csv')
ccost50
# Out:
#    Unnamed: 0      TotalCost
# 0           1  637197.038809
# 1           2  622419.466437
# 2           3  643880.700948
# 3           4  582048.096847
# 4           5  502536.175834
# 5           6  525969.914880

# %%
Community.loc[1,'Total Cost']=cobjectives['TotalCost'].sum()+185086.73753941155
Community.loc[1,'Total CO2']=cobjectives['TotalCO2'].sum()
Community.loc[2,'Total Cost']=ccost25['TotalCost'].sum()+185086.73753941155
Community.loc[2,'Total CO2']=cco225['TotalCO2'].sum()
Community.loc[3,'Total Cost']=ccost50['TotalCost'].sum()+185086.73753941155
Community.loc[3,'Total CO2']=cco250['TotalCO2'].sum()
Community.loc[4,'Total Cost']=ccost75['TotalCost'].sum()+185086.73753941155
Community.loc[4,'Total CO2']=cco275['TotalCO2'].sum()
Community.loc[5,'Total Cost']=ccost99['TotalCost'].sum()+185086.73753941155
Community.loc[5,'Total CO2']=cco299['TotalCO2'].sum()
Community
# Out:
#     Total Cost    Total CO2
# 1  3.52343e+06  5.71757e+06
# 2  3.60738e+06  4.70873e+06
# 3  3.69914e+06   3.6999e+06
# 4  3.87582e+06  2.69106e+06
# 5  5.19691e+06  1.72308e+06

# %%
dpathcost99=r'/Users/portia_murray/Dropbox/PhD/ICAE data/District/DNode99_TotalCost.csv'
dpathco299=r'/Users/portia_murray/Dropbox/PhD/ICAE data/District/DNode99_TotalCO2.csv'
dpathco275=r'/Users/portia_murray/Dropbox/PhD/ICAE data/District/DNode75_TotalCO2.csv'
dpathcost75=r'/Users/portia_murray/Dropbox/PhD/ICAE data/District/DNode75_TotalCost.csv'
dpathco250=r'/Users/portia_murray/Dropbox/PhD/ICAE data/District/DNode50_TotalCO2.csv'
dpathcost50=r'/Users/portia_murray/Dropbox/PhD/ICAE data/District/DNode50_TotalCost.csv'
dpathco225=r'/Users/portia_murray/Dropbox/PhD/ICAE data/District/DNode25_TotalCO2.csv'
dpathcost25=r'/Users/portia_murray/Dropbox/PhD/ICAE data/District/DNode25_TotalCost.csv'
dcost99=pd.read_csv(dpathcost99)
dco299=pd.read_csv(dpathco299)
dcost75=pd.read_csv(dpathcost75)
dco275=pd.read_csv(dpathco275)
dcost50=pd.read_csv(dpathcost50)
dco250=pd.read_csv(dpathco250)
dcost25=pd.read_csv(dpathcost25)
dco225=pd.read_csv(dpathco225)
dobjectives=pd.read_csv(r'/Users/portia_murray/Dropbox/PhD/ICAE data/District/Objectives_Cost.csv')
dcost50
# Out:
#    Unnamed: 0     TotalCost
# 0           1  1.243290e+06
# 1           2  1.211467e+06
# 2           3  1.013313e+06

# %%
District=pd.DataFrame(index=range(1,4),columns=['Total Cost','Total CO2'])

# %%
District.loc[1,'Total Cost']=dobjectives['TotalCost'].sum()+224144.0288462287
District.loc[1,'Total CO2']=dobjectives['TotalCO2'].sum()
District.loc[2,'Total Cost']=dcost25['TotalCost'].sum()+224144.0288462287
District.loc[2,'Total CO2']=dco225['TotalCO2'].sum()
District.loc[3,'Total Cost']=dcost50['TotalCost'].sum()+224144.0288462287
District.loc[3,'Total CO2']=dco250['TotalCO2'].sum()
District.loc[4,'Total Cost']=dcost75['TotalCost'].sum()+224144.0288462287
District.loc[4,'Total CO2']=dco275['TotalCO2'].sum()
District.loc[5,'Total Cost']=dcost99['TotalCost'].sum()+224144.0288462287
District.loc[5,'Total CO2']=dco299['TotalCO2'].sum()
District
# Out:
#     Total Cost    Total CO2
# 1  3.56014e+06  5.74856e+06
# 2  3.64951e+06   4.9071e+06
# 3  3.69221e+06  4.06563e+06
# 4  3.97679e+06  3.22417e+06
# 5  6.00346e+06  2.41096e+06

# %%
vpathcost99=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Village/VNode99_TotalCost.csv'
vpathco299=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Village/VNode99_TotalCO2.csv'
vpathco275=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Village/VNode75_TotalCO2.csv'
vpathcost75=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Village/VNode75_TotalCost.csv'
vpathco250=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Village/VNode50_TotalCO2.csv'
vpathcost50=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Village/VNode50_TotalCost.csv'
vpathco225=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Village/VNode25_TotalCO2.csv'
vpathcost25=r'/Users/portia_murray/Dropbox/PhD/ICAE data/Village/VNode25_TotalCost.csv'
vcost99=pd.read_csv(pathcost99)
vco299=pd.read_csv(pathco299)
vcost75=pd.read_csv(pathcost75)
vco275=pd.read_csv(pathco275)
vcost50=pd.read_csv(pathcost50)
vco250=pd.read_csv(pathco250)
vcost25=pd.read_csv(pathcost25)
vco225=pd.read_csv(pathco225)
vobjectives=pd.read_csv(r'/Users/portia_murray/Dropbox/PhD/ICAE data/Village/Objectives_Cost.csv')
vcost50
# Out:
#      Unnamed: 0      TotalCost
# 0             0    4198.477444
# 1             1    6655.136422
# 2             2   13980.711107
# 3             3    9387.244747
# 4             4    7842.263419
# 5             5   10158.067107
# 6             6   20157.747831
# 7             7    7056.832957
# 8             8   49771.958289
# 9             9    4297.704994
# 10           10    8493.192339
# 11           11    6599.376692
# 12           12    8072.020497
# 13           13   31003.727805
# 14           14   14003.728998
# 15           15   21896.106352
# 16           16    5922.818719
# 17           17   19319.437022
# 18           18    6982.991362
# 19           19   12161.771837
# 20           20    7098.472872
# 21           21   14075.422894
# 22           22   41898.074082
# 23           23    5444.846992
# 24           24   30778.095855
# 25           25    7472.522940
# 26           26   18552.905909
# 27           27   20702.293507
# 28           28   10204.806029
# ...

# %%
vcost25.sum()
# Out:
# Unnamed: 0    2.520000e+04
# TotalCost     3.880293e+06
# dtype: float64

# %%
Village=pd.DataFrame(index=range(1,2),columns=['Total Cost','Total CO2'])

# %%
Village.loc[1,'Total Cost']=3504387.10705159+291960.2103766538
Village.loc[1,'Total CO2']=6078687.84293517
Village.loc[2,'Total Cost']=3536724.49765266+291960.2103766538
Village.loc[2,'Total CO2']=5401890.67573551
Village.loc[3,'Total Cost']=3821504.59235244+291960.2103766538
Village.loc[3,'Total CO2']=4625587.25792931
Village.loc[4,'Total Cost']=4236490.58589078+291960.2103766538
Village.loc[4,'Total CO2']=4048296.34133595
Village.loc[5,'Total Cost']=6453460.83331591+291960.2103766538
Village.loc[5,'Total CO2']=3349514.48197881
Village
# Out:
#     Total Cost    Total CO2
# 1  3.79635e+06  6.07869e+06
# 2  3.82868e+06  5.40189e+06
# 3  4.11346e+06  4.62559e+06
# 4  4.52845e+06   4.0483e+06
# 5  6.74542e+06  3.34951e+06

# %%
Village2=Village/1E6
Community2=Community/1E6
District2=District/1E6
Neigh2=Neigh/1E6
Buildings2=Buildings/1E6

# %%
fig, ax = plt.subplots(figsize=(10,6))
plt.style.use('seaborn-whitegrid')
ax.plot(Buildings2['Total Cost'],Buildings2['Total CO2'],label='Individual buildings',marker='*',markersize=10)
ax.plot(Neigh2['Total Cost'],Neigh2['Total CO2'],label='Neighbourhoods',marker='*',markersize=10)
ax.plot(Community2['Total Cost'],Community2['Total CO2'],label='Community',marker='*',markersize=10)
ax.plot(District2['Total Cost'],District2['Total CO2'],label='District',marker='*',markersize=10)
ax.plot(Village2['Total Cost'],Village2['Total CO2'],label='Village',marker='*',markersize=10)
ax.set_xlabel('Total Cost (Millions of CHF)',fontsize=12)
ax.set_ylabel('Total Emissions (Millions of kg CO2)',fontsize=12)
ax.tick_params(axis='both', which='major', labelsize=12)
ax.legend(fontsize=12)
plt.savefig(r'/Users/portia_murray/Dropbox/PhD/ICAE data/Pareto_presentation.png',bbox_inches='tight',dpi=300)
